# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
responses = client.responses.create(
    model="gpt-5.5",
    tools=[
        {
            "type": "mcp",
            "server_label": "search_archive",
            "server_description": "Search the Inquirer archive for relevant historical articles and documents.",
            "server_url": "https://confining-award-paragraph.ngrok-free.dev/mcp",
            "require_approval": "never"
        }
    ],
    tool_choice="required",
    input="Who is the mayor of Philly in May 2026?"
)
